# %%
import pandas as pd
df=pd.read_csv('/content/📝 30 Pandas Practice Questions.csv')

# %%
df.head(5)
# Out:
#    ID    Name Department  Gender  Age   Salary JoiningDate       City  \
# 0   1    Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 1   2   Leena         HR    Male   38  53938.0  2019-02-27       Pune
# 2   3    Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 3   4  Shreya  Marketing  Female   25  31636.0  2024-02-16       Pune
# 4   5   Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
#
#    Experience  Rating
# 0         4.1     2.5
# 1         4.1     4.8
# 2         7.5     3.6
# 3         9.1     4.9
# 4         9.0     4.9

# %% [markdown]
# **Create a pivot table with Department as index, Gender as columns, and values = Salary (mean).**

# %%
df.pivot_table(
    index='Department',
    columns='Gender',
    values='Salary',
    aggfunc='mean',
    fill_value=0
)
# Out:
# Gender            Female     Male
# Department
# Finance     62384.285714  72932.5
# HR          62667.333333  54776.0
# IT          54114.000000  59804.1
# Marketing   57126.333333  65754.5
# Sales       61453.000000  74357.0
