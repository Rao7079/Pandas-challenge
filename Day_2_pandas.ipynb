# %%
import pandas as pd
data=pd.read_csv('/content/pandas practice_dataset.csv')
data.head(5)
# Out:
#    ID    Name Department  Gender  Age   Salary JoiningDate       City  \
# 0   1    Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 1   2   Leena         HR    Male   38  53938.0  2019-02-27       Pune
# 2   3    Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 3   4  Shreya  Marketing  Female   25  31636.0  2024-02-16       Pune
# 4   5   Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
#
#    Experience  Rating
# 0         4.1     2.5
# 1         4.1     4.8
# 2         7.5     3.6
# 3         9.1     4.9
# 4         9.0     4.9

# %% [markdown]
# **Select the Name and Salary columns.**

# %%
data[['Name','Salary']]
# Out:
#         Name   Salary
# 0       Ritu  74417.0
# 1      Leena  53938.0
# 2       Ajay  53664.0
# 3     Shreya  31636.0
# 4      Kavya  50080.0
# 5       Veer  57728.0
# 6      Vikas  79850.0
# 7      Nisha  56736.0
# 8       Yash  58673.0
# 9      Pooja  67505.0
# 10     Manoj  77323.0
# 11     Karan  76645.0
# 12       Ira  30854.0
# 13     Varun  54548.0
# 14     Priya  68623.0
# 15      Aman  37392.0
# 16     Naina  85680.0
# 17     Tarun      NaN
# 18       Uma  84401.0
# 19     Anita  51556.0
# 20     Meena  80859.0
# 21    Deepak  68559.0
# 22    Nikhil  56309.0
# 23     Vivek  51919.0
# 24    Bhavna      NaN
# 25     Rahul  82662.0
# 26       Raj  62970.0
# 27     Komal  74215.0
# 28     Tanvi  83370.0
# 29      Neha  42688.0
# 30     Priti  55342.0
# 31      Tina  67157.0
# 32    Hemant  32327.0
# 33     Sneha      NaN
# 34     Divya  82083.0
# 35     Arjun  70545.0
# 36     Payal  30197.0
# 37     Gauri  53509.0
# 38    Simran  64698.0
# 39     Mohan  74542.0
# ...

# %% [markdown]
# Filter employees with salary > 60,000

# %%
data[data['Salary']>60000]
# Out:
#     ID      Name Department  Gender  Age   Salary JoiningDate       City  \
# 0    1      Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 6    7     Vikas    Finance    Male   28  79850.0  2024-03-19        NaN
# 9   10     Pooja  Marketing    Male   32  67505.0  2019-08-23       Pune
# 10  11     Manoj      Sales  Female   25  77323.0  2018-12-10     Jaipur
# 11  12     Karan         HR  Female   34  76645.0  2017-02-11    Kolkata
# 14  15     Priya    Finance  Female   43  68623.0  2017-12-17        NaN
# 16  17     Naina         IT    Male   31  85680.0  2018-12-18     Jaipur
# 18  19       Uma  Marketing  Female   42  84401.0  2024-03-15     Mumbai
# 20  21     Meena         IT    Male   33  80859.0  2021-11-10      Delhi
# 21  22    Deepak    Finance  Female   33  68559.0  2022-11-27  Bengaluru
# 25  26     Rahul    Finance    Male   28  82662.0  2018-01-27     Mumbai
# 26  27       Raj         HR    Male   22  62970.0  2020-06-16    Kolkata
# ...

# %% [markdown]
# **	Filter employees from IT department with salary > 50,000**

# %%
data[(data['Salary']>50000) & (data['Department']=='IT')]
# Out:
#     ID    Name Department  Gender  Age   Salary JoiningDate       City  \
# 0    1    Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 2    3    Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 4    5   Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
# 13  14   Varun         IT    Male   40  54548.0  2019-06-09      Delhi
# 16  17   Naina         IT    Male   31  85680.0  2018-12-18     Jaipur
# 19  20   Anita         IT    Male   27  51556.0  2019-10-17     Jaipur
# 20  21   Meena         IT    Male   33  80859.0  2021-11-10      Delhi
# 22  23  Nikhil         IT  Female   41  56309.0  2021-09-25       Pune
# 23  24   Vivek         IT  Female   32  51919.0  2017-11-22      Delhi
# 31  32    Tina         IT    Male   24  67157.0  2024-01-08    Kolkata
#
#     Experience  Rating
# 0          4.1     2.5
# 2          7.5     3.6
# 4          9.0     4.9
# 13         7.0     4.2
# 16         5.9     4.0
# 19         3.0     3.8
# ...

# %% [markdown]
# **Select the first 10 rows using.iloc**

# %%
first_10=data.iloc[:10]
print(first_10)
# Out:
#    ID    Name Department  Gender  Age   Salary JoiningDate       City  \
# 0   1    Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 1   2   Leena         HR    Male   38  53938.0  2019-02-27       Pune
# 2   3    Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 3   4  Shreya  Marketing  Female   25  31636.0  2024-02-16       Pune
# 4   5   Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
# 5   6    Veer    Finance  Female   44  57728.0  2022-07-04        NaN
# 6   7   Vikas    Finance    Male   28  79850.0  2024-03-19        NaN
# 7   8   Nisha    Finance  Female   34  56736.0  2024-07-13    Kolkata
# 8   9    Yash    Finance    Male   36  58673.0  2018-08-26  Bengaluru
# 9  10   Pooja  Marketing    Male   32  67505.0  2019-08-23       Pune
#
#    Experience  Rating
# 0         4.1     2.5
# 1         4.1     4.8
# 2         7.5     3.6
# 3         9.1     4.9
# 4         9.0     4.9
# 5         8.0     4.6
# 6         6.8     3.2
# ...

# %% [markdown]
# **Select rows where Age is between 25 and 30**

# %%
data[(data['Age']>25)&(data['Age']<50)]
# Out:
#     ID      Name Department  Gender  Age   Salary JoiningDate       City  \
# 0    1      Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 1    2     Leena         HR    Male   38  53938.0  2019-02-27       Pune
# 2    3      Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 4    5     Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
# 5    6      Veer    Finance  Female   44  57728.0  2022-07-04        NaN
# 6    7     Vikas    Finance    Male   28  79850.0  2024-03-19        NaN
# 7    8     Nisha    Finance  Female   34  56736.0  2024-07-13    Kolkata
# 8    9      Yash    Finance    Male   36  58673.0  2018-08-26  Bengaluru
# 9   10     Pooja  Marketing    Male   32  67505.0  2019-08-23       Pune
# 11  12     Karan         HR  Female   34  76645.0  2017-02-11    Kolkata
# 12  13       Ira    Finance  Female   28  30854.0  2022-12-16       Pune
# 13  14     Varun         IT    Male   40  54548.0  2019-06-09      Delhi
# ...
