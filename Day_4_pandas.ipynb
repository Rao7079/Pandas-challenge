# %%
import pandas as pd
df=pd.read_csv('/content/pandas practice_dataset.csv')

# %% [markdown]
# **Sort the dataframe by Salary in descending order.**

# %%
df.sort_values(by='Salary',ascending=False)
# Out:
#     ID      Name Department  Gender  Age   Salary JoiningDate       City  \
# 16  17     Naina         IT    Male   31  85680.0  2018-12-18     Jaipur
# 18  19       Uma  Marketing  Female   42  84401.0  2024-03-15     Mumbai
# 28  29     Tanvi  Marketing    Male   41  83370.0  2019-05-07    Chennai
# 25  26     Rahul    Finance    Male   28  82662.0  2018-01-27     Mumbai
# 34  35     Divya    Finance  Female   29  82083.0  2023-03-26     Mumbai
# 47  48     Rohit         HR    Male   41  81663.0  2019-11-05        NaN
# 20  21     Meena         IT    Male   33  80859.0  2021-11-10      Delhi
# 6    7     Vikas    Finance    Male   28  79850.0  2024-03-19        NaN
# 10  11     Manoj      Sales  Female   25  77323.0  2018-12-10     Jaipur
# 11  12     Karan         HR  Female   34  76645.0  2017-02-11    Kolkata
# 39  40     Mohan  Marketing    Male   31  74542.0  2023-01-17      Delhi
# 0    1      Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# ...

# %% [markdown]
# **	Set ID as the index**

# %%
df.set_index('ID')
# Out:
#         Name Department  Gender  Age   Salary JoiningDate       City  \
# ID
# 1       Ritu         IT    Male   28  74417.0  2017-05-18       Pune
# 2      Leena         HR    Male   38  53938.0  2019-02-27       Pune
# 3       Ajay         IT    Male   41  53664.0  2025-01-11  Bengaluru
# 4     Shreya  Marketing  Female   25  31636.0  2024-02-16       Pune
# 5      Kavya         IT    Male   26  50080.0  2021-09-22  Bengaluru
# 6       Veer    Finance  Female   44  57728.0  2022-07-04        NaN
# 7      Vikas    Finance    Male   28  79850.0  2024-03-19        NaN
# 8      Nisha    Finance  Female   34  56736.0  2024-07-13    Kolkata
# 9       Yash    Finance    Male   36  58673.0  2018-08-26  Bengaluru
# 10     Pooja  Marketing    Male   32  67505.0  2019-08-23       Pune
# 11     Manoj      Sales  Female   25  77323.0  2018-12-10     Jaipur
# 12     Karan         HR  Female   34  76645.0  2017-02-11    Kolkata
# ...

# %% [markdown]
# **Reset the index.**

# %%
new_df = df.reset_index()
print(new_df)
# Out:
#     index  ID      Name Department  Gender  Age   Salary JoiningDate  \
# 0       0   1      Ritu         IT    Male   28  74417.0  2017-05-18
# 1       1   2     Leena         HR    Male   38  53938.0  2019-02-27
# 2       2   3      Ajay         IT    Male   41  53664.0  2025-01-11
# 3       3   4    Shreya  Marketing  Female   25  31636.0  2024-02-16
# 4       4   5     Kavya         IT    Male   26  50080.0  2021-09-22
# 5       5   6      Veer    Finance  Female   44  57728.0  2022-07-04
# 6       6   7     Vikas    Finance    Male   28  79850.0  2024-03-19
# 7       7   8     Nisha    Finance  Female   34  56736.0  2024-07-13
# 8       8   9      Yash    Finance    Male   36  58673.0  2018-08-26
# 9       9  10     Pooja  Marketing    Male   32  67505.0  2019-08-23
# 10     10  11     Manoj      Sales  Female   25  77323.0  2018-12-10
# 11     11  12     Karan         HR  Female   34  76645.0  2017-02-11
# 12     12  13       Ira    Finance  Female   28  30854.0  2022-12-16
# ...
